# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ## Scrap Contents for the required URLs
# City,country,population,coordination

# %%
cities = [
            "London"
            ,"Paris"
            ,"Berlin"
            ,"Moscow"
            ,"Istanbul"
            ,"Barcelona"
            ,'Saint Petersburg'
            ,'Madrid'
            ,'Kyiv'
            ,'Rome'
            ,'Bucharest'
            ,'Minsk'
            ,'Vienna']
soups=[]
url_wiki = "https://en.wikipedia.org/wiki/"
headers = {'Accept-Language': 'en-US,en;q=0.8'}

for city in cities:
    response = requests.get(url_wiki+city, headers = headers)
    if response.status_code == 200:
        soups.append(BeautifulSoup(response.content, "html.parser"))
    else:
        print(f"city {city} doesn't have a wiki")
        soups.append("")

# %%
country = []
coordinate = []
pop_des = []
pop_value = []

# %%
for i,city in enumerate(cities):
    table_name = "table.infobox.ib-settlement.vcard > tbody "
    for trs in soups[i].select(table_name + " tr"):
        #Find Country
        if trs and ( "Country" in trs.get_text()):
           country.append(trs.findNext('td').get_text().strip())
            
        # Find Coordinate
        elif trs and ( "Coordinates" in trs.get_text()):
            coordinate.append(trs.findNext('span').get_text().split("/")[1].strip().replace(u'\ufeff', ''))
        # Find Population
        elif trs and ( "Population" in trs.get_text()):
            #description
            pop_des.append(trs.findNext('th').get_text().split("[")[0].replace(u'\xa0', ' '))
            #population value
            x=trs.findNext('td').get_text()
            x=x.replace(",","").split("[")[0]
            try:
                x= int(x)
                pop_value.append(x)
            except:
                pop_value.append("NotAvailable")
            break

# %%
len(cities)==len(country) == len(coordinate) == len(pop_des) == len(pop_value)
# Out:
# True

# %%
cities_df = pd.DataFrame(
    {"cities": cities,
     "country": country,
     "coordinate": coordinate,
     "pop_des": pop_des,
     "pop_value":pop_value
    }
)

# %%
cities_df
# Out:
#               cities   country              coordinate  \
# 0             London   England    51.50722°N 0.12750°W
# 1              Paris    France  48.856613°N 2.352222°E
# 2             Berlin   Germany   52.52000°N 13.40500°E
# 3             Moscow    Russia   55.75583°N 37.61722°E
# 4           Istanbul    Turkey   41.01361°N 28.95500°E
# 5          Barcelona     Spain        41.383°N 2.183°E
# 6   Saint Petersburg    Russia   59.93750°N 30.30861°E
# 7             Madrid     Spain    40.41667°N 3.70250°W
# 8               Kyiv   Ukraine   50.45000°N 30.52333°E
# 9               Rome  Italy[a]   41.89333°N 12.48278°E
# 10         Bucharest   Romania   44.43250°N 26.10389°E
# 11             Minsk   Belarus       53.900°N 27.567°E
# 12            Vienna   Austria       48.200°N 16.367°E
#
#                                   pop_des     pop_value
# 0   Population (2021 except where stated)       8799800
# 1                  Population (Jan. 2019)       2165423
# 2                       Population (2021)       3677472
# 3                Population (2021 Census)      13010112
# 4           Population (31 December 2021)      15840900
# 5                       Population (2018)       1620343
# 6                              Population       5351935
# 7                       Population (2018)       3223334
# 8             Population (1 January 2021)       2962180
# 9           Population (31 December 2019)  NotAvailable
# 10               Population (2022 census)       1716983
# 11             Population (1 January 2021       1996553
# 12                             Population  NotAvailable

# %% [markdown]
# ## Get Weather from API

# %%
import requests
import json
from api_key import API_key

# %%
def ConvertCoord(coord):
    #convert lat and long
    lat,long = coord.replace("°E","").replace("°N","").split(" ")
    if lat.find("°S") != -1 :
        lat="-" + lat.replace("°S","")
    if long.find("°W") != -1 :
        long="-" + long.replace("°W","")
    try:
        lat= float(lat)
        long= float(long)
    except:
        print("ERROR, COORDINATES are not Convertable")
    return (lat,long)

# %%
coor= "52.52000°N 13.40500°E"  
lat,long = ConvertCoord(coor)
print(lat,long)
url_weather= f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={long}&appid={API_key}"
weather_response = requests.get(url_weather)
weather_json_l= weather_response.json()
#print(json.dumps(weather_json_l, indent=2))
# Out:
# 52.52 13.405

# %%
weather_json_l=[]
for coor in cities_df.coordinate:
    
    lat,long = ConvertCoord(coor)
    url_weather= f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={long}&appid={API_key}&units=metric"
    weather_response = requests.get(url_weather)
    if weather_response.status_code != 200:
        print(weather_response.text)
        weather_json = ""
    else:
        weather_json_l.append(weather_response.json())

# %%
# from pprint import pprint
# pprint(weather_json_l[0])
# Out:
# {'city': {'coord': {'lat': 51.5085, 'lon': -0.1257},
#           'country': 'GB',
#           'id': 2643743,
#           'name': 'London',
#           'population': 1000000,
#           'sunrise': 1672733153,
#           'sunset': 1672761804,
#           'timezone': 0},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 100},
#            'dt': 1672758000,
#            'dt_txt': '2023-01-03 15:00:00',
#            'main': {'feels_like': 9.45,
#                     'grnd_level': 1014,
#                     'humidity': 90,
#                     'pressure': 1018,
#                     'sea_level': 1018,
#                     'temp': 10.04,
#                     'temp_kf': -0.5,
#                     'temp_max': 10.54,
#                     'temp_min': 10.04},
#            'pop': 0.84,
#            'rain': {'3h': 0.37},
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 211, 'gust': 16.97, 'speed': 8.06}},
#           {'clouds': {'all': 100},
#            'dt': 1672768800,
#            'dt_txt': '2023-01-03 18:00:00',
#            'main': {'feels_like': 10,
#                     'grnd_level': 1012,
#                     'humidity': 89,
#                     'pressure': 1016,
#                     'sea_level': 1016,
#                     'temp': 10.56,
#                     'temp_kf': -0.39,
#                     'temp_max': 10.95,
#                     'temp_min': 10.56},
#            'pop': 1,
#            'rain': {'3h': 2.28},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 208, 'gust': 19.49, 'speed': 8.6}},
#           {'clouds': {'all': 100},
#            'dt': 1672779600,
#            'dt_txt': '2023-01-03 21:00:00',
#            'main': {'feels_like': 11.24,
#                     'grnd_level': 1011,
#                     'humidity': 91,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 11.64,
#                     'temp_kf': 0,
#                     'temp_max': 11.64,
#                     'temp_min': 11.64},
#            'pop': 1,
#            'rain': {'3h': 1.43},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 217, 'gust': 17.14, 'speed': 8.09}},
#           {'clouds': {'all': 100},
#            'dt': 1672790400,
#            'dt_txt': '2023-01-04 00:00:00',
#            'main': {'feels_like': 12.12,
#                     'grnd_level': 1011,
#                     'humidity': 86,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 12.56,
#                     'temp_kf': 0,
#                     'temp_max': 12.56,
#                     'temp_min': 12.56},
#            'pop': 1,
#            'rain': {'3h': 0.41},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 231, 'gust': 17.42, 'speed': 8.38}},
#           {'clouds': {'all': 100},
#            'dt': 1672801200,
#            'dt_txt': '2023-01-04 03:00:00',
#            'main': {'feels_like': 11.87,
#                     'grnd_level': 1011,
#                     'humidity': 83,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 12.41,
#                     'temp_kf': 0,
#                     'temp_max': 12.41,
#                     'temp_min': 12.41},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 230, 'gust': 17.18, 'speed': 8.48}},
#           {'clouds': {'all': 100},
#            'dt': 1672812000,
#            'dt_txt': '2023-01-04 06:00:00',
#            'main': {'feels_like': 11.58,
#                     'grnd_level': 1011,
#                     'humidity': 87,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 12.05,
#                     'temp_kf': 0,
#                     'temp_max': 12.05,
#                     'temp_min': 12.05},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 230, 'gust': 17.1, 'speed': 8.09}},
#           {'clouds': {'all': 100},
#            'dt': 1672822800,
#            'dt_txt': '2023-01-04 09:00:00',
#            'main': {'feels_like': 11.78,
#                     'grnd_level': 1011,
#                     'humidity': 87,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 12.23,
#                     'temp_kf': 0,
#                     'temp_max': 12.23,
#                     'temp_min': 12.23},
#            'pop': 0.32,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 232, 'gust': 16.59, 'speed': 7.39}},
#           {'clouds': {'all': 100},
#            'dt': 1672833600,
#            'dt_txt': '2023-01-04 12:00:00',
#            'main': {'feels_like': 12.71,
#                     'grnd_level': 1011,
#                     'humidity': 77,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 13.31,
#                     'temp_kf': 0,
#                     'temp_max': 13.31,
#                     'temp_min': 13.31},
#            'pop': 0.26,
#            'rain': {'3h': 0.25},
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 246, 'gust': 15.42, 'speed': 7.46}},
#           {'clouds': {'all': 97},
#            'dt': 1672844400,
#            'dt_txt': '2023-01-04 15:00:00',
#            'main': {'feels_like': 11.85,
#                     'grnd_level': 1012,
#                     'humidity': 75,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 12.58,
#                     'temp_kf': 0,
#                     'temp_max': 12.58,
#                     'temp_min': 12.58},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 250, 'gust': 17.53, 'speed': 7.07}},
#           {'clouds': {'all': 98},
#            'dt': 1672855200,
#            'dt_txt': '2023-01-04 18:00:00',
#            'main': {'feels_like': 10.53,
#                     'grnd_level': 1013,
#                     'humidity': 79,
#                     'pressure': 1016,
#                     'sea_level': 1016,
#                     'temp': 11.28,
#                     'temp_kf': 0,
#                     'temp_max': 11.28,
#                     'temp_min': 11.28},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 254, 'gust': 14.37, 'speed': 6.59}},
#           {'clouds': {'all': 100},
#            'dt': 1672866000,
#            'dt_txt': '2023-01-04 21:00:00',
#            'main': {'feels_like': 10.12,
#                     'grnd_level': 1015,
#                     'humidity': 73,
#                     'pressure': 1018,
#                     'sea_level': 1018,
#                     'temp': 11.05,
#                     'temp_kf': 0,
#                     'temp_max': 11.05,
#                     'temp_min': 11.05},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 264, 'gust': 13.57, 'speed': 6.46}},
#           {'clouds': {'all': 100},
#            'dt': 1672876800,
#            'dt_txt': '2023-01-05 00:00:00',
#            'main': {'feels_like': 9.96,
#                     'grnd_level': 1016,
#                     'humidity': 76,
#                     'pressure': 1019,
#                     'sea_level': 1019,
#                     'temp': 10.84,
#                     'temp_kf': 0,
#                     'temp_max': 10.84,
#                     'temp_min': 10.84},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 255, 'gust': 12.16, 'speed': 5.54}},
#           {'clouds': {'all': 100},
#            'dt': 1672887600,
#            'dt_txt': '2023-01-05 03:00:00',
#            'main': {'feels_like': 7.77,
#                     'grnd_level': 1017,
#                     'humidity': 83,
#                     'pressure': 1020,
#                     'sea_level': 1020,
#                     'temp': 9.92,
#                     'temp_kf': 0,
#                     'temp_max': 9.92,
#                     'temp_min': 9.92},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 259, 'gust': 11, 'speed': 4.3}},
#           {'clouds': {'all': 90},
#            'dt': 1672898400,
#            'dt_txt': '2023-01-05 06:00:00',
#            'main': {'feels_like': 6.58,
#                     'grnd_level': 1018,
#                     'humidity': 88,
#                     'pressure': 1021,
#                     'sea_level': 1021,
#                     'temp': 8.98,
#                     'temp_kf': 0,
#                     'temp_max': 8.98,
#                     'temp_min': 8.98},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 252, 'gust': 11.04, 'speed': 4.37}},
#           {'clouds': {'all': 100},
#            'dt': 1672909200,
#            'dt_txt': '2023-01-05 09:00:00',
#            'main': {'feels_like': 7.93,
#                     'grnd_level': 1018,
#                     'humidity': 81,
#                     'pressure': 1021,
#                     'sea_level': 1021,
#                     'temp': 9.78,
#                     'temp_kf': 0,
#                     'temp_max': 9.78,
#                     'temp_min': 9.78},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 241, 'gust': 9.63, 'speed': 3.59}},
#           {'clouds': {'all': 100},
#            'dt': 1672920000,
#            'dt_txt': '2023-01-05 12:00:00',
#            'main': {'feels_like': 9.55,
#                     'grnd_level': 1017,
#                     'humidity': 80,
#                     'pressure': 1020,
#                     'sea_level': 1020,
#                     'temp': 10.37,
#                     'temp_kf': 0,
#                     'temp_max': 10.37,
#                     'temp_min': 10.37},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 216, 'gust': 12.01, 'speed': 3.47}},
#           {'clouds': {'all': 100},
#            'dt': 1672930800,
#            'dt_txt': '2023-01-05 15:00:00',
#            'main': {'feels_like': 11.66,
#                     'grnd_level': 1016,
#                     'humidity': 81,
#                     'pressure': 1019,
#                     'sea_level': 1019,
#                     'temp': 12.26,
#                     'temp_kf': 0,
#                     'temp_max': 12.26,
#                     'temp_min': 12.26},
#            'pop': 0.2,
#            'rain': {'3h': 0.19},
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 225, 'gust': 12.66, 'speed': 4.94}},
#           {'clouds': {'all': 100},
#            'dt': 1672941600,
#            'dt_txt': '2023-01-05 18:00:00',
#            'main': {'feels_like': 10.89,
#                     'grnd_level': 1015,
#                     'humidity': 74,
#                     'pressure': 1018,
#                     'sea_level': 1018,
#                     'temp': 11.73,
#                     'temp_kf': 0,
#                     'temp_max': 11.73,
#                     'temp_min': 11.73},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 218, 'gust': 13.72, 'speed': 5.51}},
#           {'clouds': {'all': 100},
#            'dt': 1672952400,
#            'dt_txt': '2023-01-05 21:00:00',
#            'main': {'feels_like': 10.35,
#                     'grnd_level': 1014,
#                     'humidity': 82,
#                     'pressure': 1017,
#                     'sea_level': 1017,
#                     'temp': 11.05,
#                     'temp_kf': 0,
#                     'temp_max': 11.05,
#                     'temp_min': 11.05},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 221, 'gust': 15.25, 'speed': 6.26}},
#           {'clouds': {'all': 100},
#            'dt': 1672963200,
#            'dt_txt': '2023-01-06 00:00:00',
#            'main': {'feels_like': 11.05,
#                     'grnd_level': 1013,
#                     'humidity': 81,
#                     'pressure': 1016,
#                     'sea_level': 1016,
#                     'temp': 11.71,
#                     'temp_kf': 0,
#                     'temp_max': 11.71,
#                     'temp_min': 11.71},
#            'pop': 0.02,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 225, 'gust': 15.35, 'speed': 7.09}},
#           {'clouds': {'all': 100},
#            'dt': 1672974000,
#            'dt_txt': '2023-01-06 03:00:00',
#            'main': {'feels_like': 6.38,
#                     'grnd_level': 1014,
#                     'humidity': 81,
#                     'pressure': 1017,
#                     'sea_level': 1017,
#                     'temp': 8.66,
#                     'temp_kf': 0,
#                     'temp_max': 8.66,
#                     'temp_min': 8.66},
#            'pop': 1,
#            'rain': {'3h': 2.1},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 266, 'gust': 10.2, 'speed': 3.95}},
#           {'clouds': {'all': 84},
#            'dt': 1672984800,
#            'dt_txt': '2023-01-06 06:00:00',
#            'main': {'feels_like': 5.29,
#                     'grnd_level': 1015,
#                     'humidity': 83,
#                     'pressure': 1018,
#                     'sea_level': 1018,
#                     'temp': 7.85,
#                     'temp_kf': 0,
#                     'temp_max': 7.85,
#                     'temp_min': 7.85},
#            'pop': 0.72,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 261, 'gust': 9.54, 'speed': 4.14}},
#           {'clouds': {'all': 16},
#            'dt': 1672995600,
#            'dt_txt': '2023-01-06 09:00:00',
#            'main': {'feels_like': 5.21,
#                     'grnd_level': 1017,
#                     'humidity': 87,
#                     'pressure': 1020,
#                     'sea_level': 1020,
#                     'temp': 6.78,
#                     'temp_kf': 0,
#                     'temp_max': 6.78,
#                     'temp_min': 6.78},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 234, 'gust': 6.02, 'speed': 2.26}},
#           {'clouds': {'all': 43},
#            'dt': 1673006400,
#            'dt_txt': '2023-01-06 12:00:00',
#            'main': {'feels_like': 6.7,
#                     'grnd_level': 1017,
#                     'humidity': 73,
#                     'pressure': 1020,
#                     'sea_level': 1020,
#                     'temp': 8.28,
#                     'temp_kf': 0,
#                     'temp_max': 8.28,
#                     'temp_min': 8.28},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 222, 'gust': 5.15, 'speed': 2.62}},
#           {'clouds': {'all': 100},
#            'dt': 1673017200,
#            'dt_txt': '2023-01-06 15:00:00',
#            'main': {'feels_like': 6.57,
#                     'grnd_level': 1016,
#                     'humidity': 79,
#                     'pressure': 1019,
#                     'sea_level': 1019,
#                     'temp': 8.37,
#                     'temp_kf': 0,
#                     'temp_max': 8.37,
#                     'temp_min': 8.37},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 185, 'gust': 7.6, 'speed': 2.98}},
#           {'clouds': {'all': 100},
#            'dt': 1673028000,
#            'dt_txt': '2023-01-06 18:00:00',
#            'main': {'feels_like': 5.55,
#                     'grnd_level': 1014,
#                     'humidity': 89,
#                     'pressure': 1017,
#                     'sea_level': 1017,
#                     'temp': 7.97,
#                     'temp_kf': 0,
#                     'temp_max': 7.97,
#                     'temp_min': 7.97},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 175, 'gust': 10.63, 'speed': 3.91}},
#           {'clouds': {'all': 100},
#            'dt': 1673038800,
#            'dt_txt': '2023-01-06 21:00:00',
#            'main': {'feels_like': 5.95,
#                     'grnd_level': 1010,
#                     'humidity': 93,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 8.76,
#                     'temp_kf': 0,
#                     'temp_max': 8.76,
#                     'temp_min': 8.76},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 175, 'gust': 13.64, 'speed': 5.23}},
#           {'clouds': {'all': 100},
#            'dt': 1673049600,
#            'dt_txt': '2023-01-07 00:00:00',
#            'main': {'feels_like': 10.22,
#                     'grnd_level': 1007,
#                     'humidity': 87,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 10.81,
#                     'temp_kf': 0,
#                     'temp_max': 10.81,
#                     'temp_min': 10.81},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 197, 'gust': 15.71, 'speed': 6.78}},
#           {'clouds': {'all': 100},
#            'dt': 1673060400,
#            'dt_txt': '2023-01-07 03:00:00',
#            'main': {'feels_like': 10.5,
#                     'grnd_level': 1004,
#                     'humidity': 84,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 11.14,
#                     'temp_kf': 0,
#                     'temp_max': 11.14,
#                     'temp_min': 11.14},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 197, 'gust': 17.59, 'speed': 8.28}},
#           {'clouds': {'all': 100},
#            'dt': 1673071200,
#            'dt_txt': '2023-01-07 06:00:00',
#            'main': {'feels_like': 10.38,
#                     'grnd_level': 1000,
#                     'humidity': 86,
#                     'pressure': 1004,
#                     'sea_level': 1004,
#                     'temp': 10.98,
#                     'temp_kf': 0,
#                     'temp_max': 10.98,
#                     'temp_min': 10.98},
#            'pop': 0.86,
#            'rain': {'3h': 1.36},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 192, 'gust': 18.12, 'speed': 9.22}},
#           {'clouds': {'all': 100},
#            'dt': 1673082000,
#            'dt_txt': '2023-01-07 09:00:00',
#            'main': {'feels_like': 10.17,
#                     'grnd_level': 997,
#                     'humidity': 88,
#                     'pressure': 1000,
#                     'sea_level': 1000,
#                     'temp': 10.74,
#                     'temp_kf': 0,
#                     'temp_max': 10.74,
#                     'temp_min': 10.74},
#            'pop': 1,
#            'rain': {'3h': 3.66},
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'moderate rain',
#                         'icon': '10d',
#                         'id': 501,
#                         'main': 'Rain'}],
#            'wind': {'deg': 186, 'gust': 20.01, 'speed': 8.97}},
#           {'clouds': {'all': 100},
#            'dt': 1673092800,
#            'dt_txt': '2023-01-07 12:00:00',
#            'main': {'feels_like': 5.43,
#                     'grnd_level': 998,
#                     'humidity': 80,
#                     'pressure': 1001,
#                     'sea_level': 1001,
#                     'temp': 8.54,
#                     'temp_kf': 0,
#                     'temp_max': 8.54,
#                     'temp_min': 8.54},
#            'pop': 1,
#            'rain': {'3h': 1.88},
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 275, 'gust': 14.81, 'speed': 5.87}},
#           {'clouds': {'all': 83},
#            'dt': 1673103600,
#            'dt_txt': '2023-01-07 15:00:00',
#            'main': {'feels_like': 5.78,
#                     'grnd_level': 999,
#                     'humidity': 71,
#                     'pressure': 1002,
#                     'sea_level': 1002,
#                     'temp': 8.66,
#                     'temp_kf': 0,
#                     'temp_max': 8.66,
#                     'temp_min': 8.66},
#            'pop': 0.14,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 233, 'gust': 13.26, 'speed': 5.34}},
#           {'clouds': {'all': 76},
#            'dt': 1673114400,
#            'dt_txt': '2023-01-07 18:00:00',
#            'main': {'feels_like': 4.39,
#                     'grnd_level': 1000,
#                     'humidity': 78,
#                     'pressure': 1003,
#                     'sea_level': 1003,
#                     'temp': 7.65,
#                     'temp_kf': 0,
#                     'temp_max': 7.65,
#                     'temp_min': 7.65},
#            'pop': 0.34,
#            'rain': {'3h': 0.13},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 217, 'gust': 13.73, 'speed': 5.64}},
#           {'clouds': {'all': 75},
#            'dt': 1673125200,
#            'dt_txt': '2023-01-07 21:00:00',
#            'main': {'feels_like': 4.17,
#                     'grnd_level': 999,
#                     'humidity': 79,
#                     'pressure': 1002,
#                     'sea_level': 1002,
#                     'temp': 7.37,
#                     'temp_kf': 0,
#                     'temp_max': 7.37,
#                     'temp_min': 7.37},
#            'pop': 0.37,
#            'rain': {'3h': 0.24},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 217, 'gust': 12.85, 'speed': 5.3}},
#           {'clouds': {'all': 87},
#            'dt': 1673136000,
#            'dt_txt': '2023-01-08 00:00:00',
#            'main': {'feels_like': 4.95,
#                     'grnd_level': 996,
#                     'humidity': 82,
#                     'pressure': 999,
#                     'sea_level': 999,
#                     'temp': 8.25,
#                     'temp_kf': 0,
#                     'temp_max': 8.25,
#                     'temp_min': 8.25},
#            'pop': 0.19,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 199, 'gust': 15.17, 'speed': 6.2}},
#           {'clouds': {'all': 100},
#            'dt': 1673146800,
#            'dt_txt': '2023-01-08 03:00:00',
#            'main': {'feels_like': 5.56,
#                     'grnd_level': 992,
#                     'humidity': 86,
#                     'pressure': 995,
#                     'sea_level': 995,
#                     'temp': 8.93,
#                     'temp_kf': 0,
#                     'temp_max': 8.93,
#                     'temp_min': 8.93},
#            'pop': 0.94,
#            'rain': {'3h': 1},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 199, 'gust': 13.71, 'speed': 7.02}},
#           {'clouds': {'all': 100},
#            'dt': 1673157600,
#            'dt_txt': '2023-01-08 06:00:00',
#            'main': {'feels_like': 5.77,
#                     'grnd_level': 988,
#                     'humidity': 91,
#                     'pressure': 991,
#                     'sea_level': 991,
#                     'temp': 8.89,
#                     'temp_kf': 0,
#                     'temp_max': 8.89,
#                     'temp_min': 8.89},
#            'pop': 1,
#            'rain': {'3h': 3.68},
#            'sys': {'pod': 'n'},
#            'visibility': 6168,
#            'weather': [{'description': 'moderate rain',
#                         'icon': '10n',
#                         'id': 501,
#                         'main': 'Rain'}],
#            'wind': {'deg': 204, 'gust': 13.15, 'speed': 6.18}},
#           {'clouds': {'all': 100},
#            'dt': 1673168400,
#            'dt_txt': '2023-01-08 09:00:00',
#            'main': {'feels_like': 5.45,
#                     'grnd_level': 985,
#                     'humidity': 90,
#                     'pressure': 989,
#                     'sea_level': 989,
#                     'temp': 7.96,
#                     'temp_kf': 0,
#                     'temp_max': 7.96,
#                     'temp_min': 7.96},
#            'pop': 1,
#            'rain': {'3h': 7.29},
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'moderate rain',
#                         'icon': '10d',
#                         'id': 501,
#                         'main': 'Rain'}],
#            'wind': {'deg': 296, 'gust': 8.58, 'speed': 4.09}},
#           {'clouds': {'all': 88},
#            'dt': 1673179200,
#            'dt_txt': '2023-01-08 12:00:00',
#            'main': {'feels_like': 5.34,
#                     'grnd_level': 987,
#                     'humidity': 77,
#                     'pressure': 990,
#                     'sea_level': 990,
#                     'temp': 8.35,
#                     'temp_kf': 0,
#                     'temp_max': 8.35,
#                     'temp_min': 8.35},
#            'pop': 0.8,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 252, 'gust': 11.47, 'speed': 5.47}}],
#  'message': 0}

# %%
cities_weath = {"cities":[]
                ,"forcast_time":[]
                ,"outlook":[]
                ,"temperature":[]
                ,"feels_like":[]
                ,"wind_speed":[]
                ,"rain_prob":[]
                }

for j,city_json in enumerate(weather_json_l):
    current_city = cities_df.loc[j].cities
    for i in range(len(city_json["list"])):
        cities_weath["cities"].append(current_city)
        cities_weath["forcast_time"].append(city_json["list"][i]["dt_txt"])
        cities_weath["temperature"].append(city_json["list"][i]["main"]["temp"])
        cities_weath["outlook"].append(city_json["list"][i]["weather"][0]["description"])
        cities_weath["feels_like"].append(city_json["list"][i]["main"]["feels_like"])
        cities_weath["wind_speed"].append(city_json["list"][i]["wind"]["speed"])
        cities_weath["rain_prob"].append(city_json["list"][i]["pop"])

# %%
cities_weather_df = pd.DataFrame(cities_weath)

# %%
cities_weather_df
# Out:
#      cities         forcast_time          outlook  temperature  feels_like  \
# 0    London  2023-01-03 15:00:00       light rain        10.04        9.45
# 1    London  2023-01-03 18:00:00       light rain        10.56       10.00
# 2    London  2023-01-03 21:00:00       light rain        11.64       11.24
# 3    London  2023-01-04 00:00:00       light rain        12.56       12.12
# 4    London  2023-01-04 03:00:00  overcast clouds        12.41       11.87
# ..      ...                  ...              ...          ...         ...
# 515  Vienna  2023-01-08 00:00:00  overcast clouds         5.25        5.25
# 516  Vienna  2023-01-08 03:00:00  overcast clouds         4.52        3.44
# 517  Vienna  2023-01-08 06:00:00  overcast clouds         3.93        2.32
# 518  Vienna  2023-01-08 09:00:00  overcast clouds         5.16        2.48
# 519  Vienna  2023-01-08 12:00:00  overcast clouds         7.83        4.31
#
#      wind_speed  rain_prob
# 0          8.06       0.84
# 1          8.60       1.00
# 2          8.09       1.00
# 3          8.38       1.00
# 4          8.48       0.00
# ..          ...        ...
# 515        1.18       0.00
# 516        1.47       0.00
# 517        1.82       0.00
# 518        3.32       0.00
# 519        6.51       0.00
#
# [520 rows x 7 columns]
